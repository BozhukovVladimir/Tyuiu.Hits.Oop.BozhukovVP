// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания №6

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Movie в C#, который будет представлять информацию о
// фильмах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Movie
{
    public string Title { get; set; }
    public string Director { get; set; }
    public int Year { get; set; }
    public double Rating { get; set; }

    public Movie(string title, string director, int year, double rating)
    {
        Title = title;
        Director = director;
        Year = year;
        Rating = rating;
    }

    public virtual string GetInfo()
    {
        return $"«{Title}» реж. {Director} ({Year}) Рейтинг: {Rating:F1}";
    }

    public virtual void UpdateRating(double newRating)
    {
        Rating = newRating;
        Console.WriteLine($"Рейтинг фильма «{Title}» обновлен: {Rating:F1}");
    }

    public virtual string Watch()
    {
        return $"Смотрим фильм «{Title}»";
    }
}
public class ActionMovie : Movie
{
    public int ExplosionCount { get; set; }
    public string MainActor { get; set; }

    public ActionMovie(string title, string director, int year, double rating, 
                       int explosions, string actor) : base(title, director, year, rating)
    {
        ExplosionCount = explosions;
        MainActor = actor;
    }
    public override string GetInfo()
    {
        return base.GetInfo() + $"\nВзрывы: {ExplosionCount}, Главный герой: {MainActor}";
    }

    public string DriveCar()
    {
        return $"В фильме «{Title}» главный герой {MainActor} виртуозно водит машину!";
    }

    public override string Watch()
    {
        return $"Запускаем боевик «{Title}» с невероятными трюками!";
    }
}
public class SciFiMovie : Movie
{
    public string Technology { get; set; }
    public bool IsDystopian { get; set; }

    public SciFiMovie(string title, string director, int year, double rating,
                      string tech, bool dystopian) : base(title, director, year, rating)
    {
        Technology = tech;
        IsDystopian = dystopian;
    }

    public override string GetInfo()
    {
        string dystopiaInfo = IsDystopian ? "Антиутопия" : "Утопия";
        return base.GetInfo() + $"\nТехнологии: {Technology}, Жанр: {dystopiaInfo}";
    }

    public string PredictFuture()
    {
        return $"Фильм «{Title}» предсказывает будущее с технологиями {Technology}";
    }

    public override void UpdateRating(double newRating)
    {
        Rating = Math.Min(newRating, 10.0); 
        Console.WriteLine($"Рейтинг научно-фантастического фильма «{Title}» установлен: {Rating:F1}");
    }
}
public class DramaMovie : Movie
{
    public string MainTheme { get; set; }
    public int EmotionalImpact { get; set; } 

    public DramaMovie(string title, string director, int year, double rating,
                      string theme, int impact) : base(title, director, year, rating)
    {
        MainTheme = theme;
        EmotionalImpact = Math.Clamp(impact, 1, 10);
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $"\nТема: {MainTheme}, Эмоциональность: {EmotionalImpact}/10";
    }

    public string Cry()
    {
        return EmotionalImpact >= 8 
            ? $"Фильм «{Title}» заставит вас плакать!" 
            : $"Фильм «{Title}» затрагивает тему {MainTheme}";
    }

    public override string Watch()
    {
        return $"Погружаемся в драму «{Title}». Приготовьте салфетки!";
    }
}
var movies = new List<Movie>
{
    new ActionMovie("Терминатор 2", "Джеймс Кэмерон", 1991, 8.6, 15, "Арнольд Шварценеггер"),
    new SciFiMovie("Бегущий по лезвию 2049", "Дени Вильнёв", 2017, 8.3, "Искусственный интеллект", true),
    new DramaMovie("Форрест Гамп", "Роберт Земекис", 1994, 8.8, "Жизненный путь", 9)
};

foreach (var movie in movies)
{
    Console.WriteLine("=== Информация о фильме ===");
    Console.WriteLine(movie.GetInfo());
    Console.WriteLine(movie.Watch());
    Console.WriteLine();
}

var action = (ActionMovie)movies[0];
Console.WriteLine(action.DriveCar());

var scifi = (SciFiMovie)movies[1];
Console.WriteLine(scifi.PredictFuture());

var drama = (DramaMovie)movies[2];
Console.WriteLine(drama.Cry());
Console.WriteLine("=== Демонстрация обновления рейтингов ===");
movies[0].UpdateRating(9.1);
movies[1].UpdateRating(11.5);
// Out:
// === Информация о фильме ===
// «Терминатор 2» реж. Джеймс Кэмерон (1991) Рейтинг: 8.6
// Взрывы: 15, Главный герой: Арнольд Шварценеггер
// Запускаем боевик «Терминатор 2» с невероятными трюками!
//
// === Информация о фильме ===
// «Бегущий по лезвию 2049» реж. Дени Вильнёв (2017) Рейтинг: 8.3
// Технологии: Искусственный интеллект, Жанр: Антиутопия
// Смотрим фильм «Бегущий по лезвию 2049»
//
// === Информация о фильме ===
// «Форрест Гамп» реж. Роберт Земекис (1994) Рейтинг: 8.8
// Тема: Жизненный путь, Эмоциональность: 9/10
// Погружаемся в драму «Форрест Гамп». Приготовьте салфетки!
//
// В фильме «Терминатор 2» главный герой Арнольд Шварценеггер виртуозно водит машину!
// Фильм «Бегущий по лезвию 2049» предсказывает будущее с технологиями Искусственный интеллект
// Фильм «Форрест Гамп» заставит вас плакать!
// === Демонстрация обновления рейтингов ===
// Рейтинг фильма «Терминатор 2» обновлен: 9.1
// ...
